# %% [markdown]
# Software is free software released under the "GNU General Public License v3.0"
#
# Copyright (c) 2022 Yuning-Jiang - yuning.jiang17@gmail.com

# %%
import pandas as pd, numpy as np
import config
import re 
from os import listdir

# %%
#Generate combined historical dataset using NVD reports from 2002 to 2020.
def generate_CWECAPEC_CombinedFile():
    list = listdir(config.report_CWECAPEC_path)
    number_files = len(list)-1
    dict = []
    dict_of_reports = {}
    for year in range(2002,2002 + number_files):
        year_in_string = str(year)
        fileName = 'NVD_'+ year_in_string + '_CWE_CAPEClabel.csv'
        dict_of_reports[year_in_string] = []
        dict_of_reports[year_in_string] = pd.read_csv(config.report_CWECAPEC_path + fileName)
        dict.append(dict_of_reports[year_in_string])
    df = pd.concat(dict, ignore_index=True)
    return df

df = generate_CWECAPEC_CombinedFile()
# print schema
print("Schema:\n\n",df.dtypes)
print("Number of vulnerability reports,columns=",df.shape)
# Out:
# Schema:
#
#  CVEID                object
# CWEID                object
# VulnerabilityType    object
# AttackPattern        object
# Report               object
# dtype: object
# Number of vulnerability reports,columns= (160093, 5)

# %%
# Remove the vulnerabilities that are rejected by NVD analysts. 
df = df[~df['Report'].str.contains('REJECT')]
# print schema
print("Schema:\n\n",df.dtypes)
print("Number of vulnerability reports,columns=",df.shape)
# Out:
# Schema:
#
#  CVEID                object
# CWEID                object
# VulnerabilityType    object
# AttackPattern        object
# Report               object
# dtype: object
# Number of vulnerability reports,columns= (150528, 5)

# %%
df['CWEID'].value_counts()
# Out:
# ['NVD-CWE-Other']         26562
# ['NVD-CWE-noinfo']        16465
# ['CWE-79']                15308
# []                        13263
# ['CWE-119']               11050
#                           ...
# ['CWE-611', 'CWE-311']        1
# ['CWE-706', 'CWE-863']        1
# ['CWE-119', 'CWE-917']        1
# ['CWE-190', 'CWE-704']        1
# ['CWE-77', 'CWE-116']         1
# Name: CWEID, Length: 835, dtype: int64

# %%
df['cweIDamount']=df["CWEID"].apply(lambda x: len(re.findall(",",str(x)))+1)

# %%
indexNames1 = df[df['CWEID'].str.contains('Missing Data') & df['cweIDamount'] == 1].index
indexNames2 = df[df['CWEID'].str.contains('NVD-CWE-Other') & df['cweIDamount'] == 1].index
indexNames3 = df[df['CWEID'].str.contains('NVD-CWE-noinfo') & df['cweIDamount'] == 1].index

# %%
df.drop(indexNames1, inplace=True)
df.drop(indexNames2 , inplace=True)
df.drop(indexNames3 , inplace=True)
len(df)
# Out:
# 107497

# %%
df = df[df['CWEID'].map(lambda d: len(d)) > 9]

# %%
df['cweIDamount'].value_counts()
# Out:
# 1    91931
# 2     2192
# 3       96
# 4       11
# 5        4
# Name: cweIDamount, dtype: int64

# %%
tempdf = df.loc[df['cweIDamount']==2]
tempdf.sample(2)
# Out:
#                  CVEID                   CWEID  \
# 146153  CVE-2020-14402  ['CWE-125', 'CWE-670']
# 155141   CVE-2020-3898   ['CWE-20', 'CWE-787']
#
#                                         VulnerabilityType  \
# 146153  ['Out-of-bounds Read', 'Always-Incorrect Contr...
# 155141  ['Improper Input Validation', 'Out-of-bounds W...
#
#                                             AttackPattern  \
# 146153                                      ['CAPEC-540']
# 155141  ['CAPEC-10', 'CAPEC-101', 'CAPEC-104', 'CAPEC-...
#
#                                                    Report  cweIDamount
# 146153  An issue was discovered in LibVNCServer before...            2
# 155141  A memory corruption issue was addressed with i...            2

# %%
tempdf = df.loc[df['cweIDamount']==3]
tempdf.sample(2)
# Out:
#                 CVEID                              CWEID  \
# 106537  CVE-2017-7778  ['CWE-119', 'CWE-125', 'CWE-787']
# 135679  CVE-2019-2304   ['CWE-20', 'CWE-787', 'CWE-190']
#
#                                         VulnerabilityType  \
# 106537  ['Improper Restriction of Operations within th...
# 135679  ['Improper Input Validation', 'Out-of-bounds W...
#
#                                             AttackPattern  \
# 106537  ['CAPEC-10', 'CAPEC-100', 'CAPEC-123', 'CAPEC-...
# 135679  ['CAPEC-10', 'CAPEC-101', 'CAPEC-104', 'CAPEC-...
#
#                                                    Report  cweIDamount
# 106537  A number of security vulnerabilities in the Gr...            3
# 135679  Integer overflow to buffer overflow due to lac...            3

# %%
tempdf = df.loc[df['cweIDamount']==4]
tempdf.sample(2)
# Out:
#                  CVEID                                         CWEID  \
# 134105  CVE-2019-19307  ['CWE-125', 'CWE-787', 'CWE-190', 'CWE-835']
# 144161  CVE-2020-11901  ['CWE-125', 'CWE-787', 'CWE-330', 'CWE-131']
#
#                                         VulnerabilityType  \
# 134105  ['Out-of-bounds Read', 'Out-of-bounds Write', ...
# 144161  ['Out-of-bounds Read', 'Out-of-bounds Write', ...
#
#                                             AttackPattern  \
# 134105                          ['CAPEC-540', 'CAPEC-92']
# 144161  ['CAPEC-540', 'CAPEC-112', 'CAPEC-485', 'CAPEC...
#
#                                                    Report  cweIDamount
# 134105  An integer overflow in parse_mqtt in mongoose....            4
# 144161  The Treck TCP/IP stack before 6.0.1.66 allows ...            4

# %%
# This method depicts the CWE-IDs with highest occurences in NVD vulnerabiliites.
cweIDcount = []
tempdf1 = df.loc[df['cweIDamount']==1]
for i in range(0, len(tempdf1)):
    cweID = tempdf1['CWEID'].values[i]
    cweID = eval(str(cweID).strip('[]'))
    cweIDcount.append(cweID)
tempdf2 = df.loc[df['cweIDamount']==2]
for i in range(0, len(tempdf2)):
    cweID = tempdf2['CWEID'].values[i]
    cweID = eval(str(cweID).strip('[]'))
    for item in cweID:
        cweIDcount.append(item)
tempdf3 = df.loc[df['cweIDamount']==3]
for i in range(0, len(tempdf3)):
    cweID = tempdf3['CWEID'].values[i]
    cweID = eval(str(cweID).strip('[]'))
    for item in cweID:
        cweIDcount.append(item)
tempdf4 = df.loc[df['cweIDamount']==4]
for i in range(0, len(tempdf4)):
    cweID = tempdf4['CWEID'].values[i]
    cweID = eval(str(cweID).strip('[]'))
    for item in cweID:
        cweIDcount.append(item)
tempdf5 = df.loc[df['cweIDamount']==5]
for i in range(0, len(tempdf5)):
    cweID = tempdf5['CWEID'].values[i]
    cweID = eval(str(cweID).strip('[]'))
    for item in cweID:
        cweIDcount.append(item)
        
from collections import Counter
len(cweIDcount), Counter(cweIDcount).most_common()
# Out:
# (96667,
#  [('CWE-79', 15410),
#   ('CWE-119', 11263),
#   ('CWE-20', 8075),
#   ('CWE-89', 6477),
#   ('CWE-200', 6428),
#   ('CWE-787', 4252),
#   ('CWE-22', 3741),
#   ('CWE-125', 3367),
#   ('CWE-352', 3035),
#   ('CWE-94', 2573),
#   ('CWE-287', 2194),
#   ('CWE-416', 2103),
#   ('CWE-78', 1675),
#   ('CWE-190', 1533),
#   ('CWE-476', 1339),
#   ('CWE-284', 989),
#   ('CWE-362', 907),
#   ('CWE-434', 794),
#   ('CWE-400', 759),
#   ('CWE-269', 741),
#   ('CWE-59', 739),
#   ('CWE-732', 712),
#   ('CWE-120', 692),
#   ('CWE-862', 609),
#   ('CWE-798', 599),
#   ('CWE-611', 591),
#   ('CWE-295', 587),
#   ('CWE-522', 544),
#   ('CWE-502', 537),
#   ('CWE-77', 532),
#   ('CWE-306', 527),
#   ('CWE-863', 484),
#   ('CWE-74', 456),
#   ('CWE-601', 432),
#   ('CWE-276', 400),
#   ('CWE-918', 386),
#   ('CWE-772', 351),
#   ('CWE-426', 351),
#   ('CWE-835', 350),
#   ('CWE-532', 303),
#   ('CWE-319', 302),
#   ('CWE-427', 262),
#   ('CWE-401', 253),
#   ('CWE-415', 252),
#   ('CWE-134', 248),
#   ('CWE-770', 243),
#   ('CWE-327', 217),
#   ('CWE-755', 199),
#   ('CWE-326', 193),
#   ('CWE-312', 193),
#   ('CWE-704', 184),
#   ('NVD-CWE-noinfo', 183),
#   ('CWE-347', 182),
#   ('CWE-384', 177),
#   ('CWE-668', 176),
#   ('CWE-617', 172),
#   ('CWE-129', 168),
#   ('CWE-908', 163),
#   ('CWE-311', 162),
#   ('CWE-369', 160),
#   ('CWE-203', 154),
#   ('CWE-345', 152),
#   ('CWE-843', 144),
#   ('CWE-665', 142),
#   ('CWE-917', 135),
#   ('CWE-330', 134),
#   ('CWE-639', 125),
#   ('CWE-209', 121),
#   ('CWE-346', 121),
#   ('CWE-674', 117),
#   ('CWE-191', 111),
#   ('CWE-613', 111),
#   ('CWE-307', 109),
#   ('CWE-404', 105),
#   ('CWE-754', 104),
#   ('CWE-1021', 96),
#   ('CWE-1188', 95),
#   ('CWE-1236', 85),
#   ('CWE-444', 84),
#   ('CWE-88', 82),
#   ('CWE-640', 79),
#   ('CWE-367', 78),
#   ('CWE-521', 78),
#   ('CWE-290', 78),
#   ('CWE-915', 75),
#   ('CWE-428', 74),
#   ('CWE-281', 74),
#   ('CWE-425', 74),
#   ('CWE-285', 72),
#   ('CWE-552', 69),
#   ('CWE-116', 61),
#   ('CWE-824', 56),
#   ('CWE-922', 55),
#   ('CWE-667', 54),
#   ('CWE-909', 52),
#   ('CWE-834', 52),
#   ('CWE-682', 48),
#   ('CWE-494', 47),
#   ('CWE-459', 47),
#   ('CWE-294', 46),
#   ('CWE-193', 46),
#   ('CWE-610', 46),
#   ('CWE-354', 43),
#   ('CWE-338', 42),
#   ('CWE-91', 42),
#   ('CWE-829', 37),
#   ('CWE-93', 34),
#   ('CWE-693', 34),
#   ('CWE-916', 33),
#   ('CWE-681', 33),
#   ('CWE-122', 33),
#   ('CWE-331', 30),
#   ('CWE-763', 28),
#   ('CWE-131', 28),
#   ('CWE-706', 27),
#   ('CWE-252', 26),
#   ('CWE-670', 26),
#   ('CWE-776', 25),
#   ('CWE-358', 25),
#   ('CWE-669', 24),
#   ('CWE-662', 24),
#   ('CWE-113', 21),
#   ('CWE-565', 19),
#   ('CWE-697', 19),
#   ('CWE-212', 19),
#   ('CWE-436', 18),
#   ('CWE-121', 17),
#   ('CWE-118', 13),
#   ('CWE-672', 13),
#   ('CWE-185', 13),
#   ('CWE-273', 12),
#   ('CWE-335', 11),
#   ('CWE-913', 11),
#   ('CWE-749', 11),
#   ('NVD-CWE-Other', 11),
#   ('CWE-90', 10),
#   ('CWE-123', 10),
#   ('CWE-297', 9),
#   ('CWE-172', 9),
#   ('CWE-266', 9),
#   ('CWE-377', 8),
#   ('CWE-332', 8),
#   ('CWE-184', 8),
#   ('CWE-538', 8),
#   ('CWE-470', 8),
#   ('CWE-288', 7),
#   ('CWE-256', 7),
#   ('CWE-441', 6),
#   ('CWE-178', 6),
#   ('CWE-838', 6),
#   ('CWE-321', 6),
#   ('CWE-80', 6),
#   ('CWE-99', 4),
#   ('CWE-924', 4),
#   ('CWE-305', 4),
#   ('CWE-23', 4),
#   ('CWE-73', 4),
#   ('CWE-250', 4),
#   ('CWE-117', 4),
#   ('CWE-822', 4),
#   ('CWE-407', 3),
#   ('CWE-920', 3),
#   ('CWE-943', 3),
#   ('CWE-707', 3),
#   ('CWE-61', 3),
#   ('CWE-385', 3),
#   ('CWE-664', 2),
#   ('CWE-642', 2),
#   ('CWE-300', 2),
#   ('CWE-471', 2),
#   ('CWE-349', 2),
#   ('CWE-201', 2),
#   ('CWE-342', 2),
#   ('CWE-270', 2),
#   ('CWE-208', 2),
#   ('CWE-649', 1),
#   ('CWE-775', 1),
#   ('CWE-774', 1),
#   ('CWE-405', 1),
#   ('CWE-317', 1),
#   ('CWE-573', 1),
#   ('CWE-406', 1),
#   ('CWE-313', 1),
#   ('CWE-778', 1),
#   ('CWE-325', 1),
#   ('CWE-268', 1),
#   ('CWE-440', 1),
#   ('CWE-280', 1),
#   ('CWE-805', 1),
#   ('CWE-261', 1),
#   ('CWE-684', 1),
#   ('CWE-114', 1),
#   ('CWE-350', 1),
#   ('CWE-364', 1),
#   ('CWE-506', 1),
#   ('CWE-303', 1),
#   ('CWE-248', 1),
#   ('CWE-757', 1),
#   ('CWE-912', 1),
#   ('CWE-1286', 1),
#   ('CWE-130', 1),
#   ('CWE-299', 1),
#   ('CWE-759', 1),
#   ('CWE-323', 1),
#   ('CWE-435', 1),
#   ('CWE-567', 1),
#   ('CWE-507', 1),
#   ('CWE-823', 1),
#   ('CWE-112', 1),
#   ('CWE-170', 1),
#   ('CWE-788', 1),
#   ('CWE-115', 1),
#   ('CWE-760', 1),
#   ('CWE-271', 1),
#   ('CWE-98', 1),
#   ('CWE-87', 1),
#   ('CWE-334', 1),
#   ('CWE-259', 1),
#   ('CWE-603', 1),
#   ('CWE-279', 1),
#   ('CWE-680', 1),
#   ('CWE-96', 1),
#   ('CWE-694', 1),
#   ('CWE-1285', 1),
#   ('CWE-183', 1),
#   ('CWE-228', 1),
#   ('CWE-214', 1)])

# %%
# This is just to extract the CWE-IDs used by NVD analysts when assigning weakness categories.
nvdcweID = list(dict.fromkeys(cweIDcount))
len(nvdcweID), nvdcweID
# Out:
# (227,
#  ['CWE-20',
#   'CWE-119',
#   'CWE-327',
#   'CWE-252',
#   'CWE-200',
#   'CWE-120',
#   'CWE-287',
#   'CWE-384',
#   'CWE-94',
#   'CWE-59',
#   'CWE-362',
#   'CWE-665',
#   'CWE-798',
#   'CWE-209',
#   'CWE-79',
#   'CWE-22',
#   'CWE-434',
#   'CWE-401',
#   'CWE-400',
#   'CWE-284',
#   'CWE-668',
#   'CWE-770',
#   'CWE-532',
#   'CWE-269',
#   'CWE-294',
#   'CWE-669',
#   'CWE-134',
#   'CWE-787',
#   'CWE-89',
#   'CWE-78',
#   'CWE-352',
#   'CWE-190',
#   'CWE-415',
#   'CWE-772',
#   'CWE-476',
#   'CWE-369',
#   'CWE-326',
#   'CWE-601',
#   'CWE-835',
#   'CWE-193',
#   'CWE-319',
#   'CWE-77',
#   'CWE-74',
#   'CWE-306',
#   'CWE-295',
#   'CWE-191',
#   'CWE-93',
#   'CWE-502',
#   'CWE-863',
#   'CWE-113',
#   'CWE-732',
#   'CWE-918',
#   'CWE-331',
#   'CWE-416',
#   'CWE-1188',
#   'CWE-338',
#   'CWE-426',
#   'CWE-91',
#   'CWE-312',
#   'CWE-613',
#   'CWE-129',
#   'CWE-909',
#   'CWE-116',
#   'CWE-640',
#   'CWE-755',
#   'CWE-916',
#   'CWE-307',
#   'CWE-824',
#   'CWE-704',
#   'CWE-611',
#   'CWE-843',
#   'CWE-681',
#   'CWE-311',
#   'CWE-649',
#   'CWE-617',
#   'CWE-494',
#   'CWE-330',
#   'CWE-404',
#   'CWE-522',
#   'CWE-125',
#   'CWE-276',
#   'CWE-682',
#   'CWE-346',
#   'CWE-273',
#   'CWE-693',
#   'CWE-347',
#   'CWE-565',
#   'CWE-697',
#   'CWE-90',
#   'CWE-377',
#   'CWE-367',
#   'CWE-521',
#   'CWE-862',
#   'CWE-428',
#   'CWE-354',
#   'CWE-335',
#   'CWE-776',
#   'CWE-829',
#   'CWE-427',
#   'CWE-203',
#   'CWE-345',
#   'CWE-1021',
#   'CWE-763',
#   'CWE-290',
#   'CWE-281',
#   'CWE-285',
#   'CWE-332',
#   'CWE-754',
#   'CWE-670',
#   'CWE-131',
#   'CWE-297',
#   'CWE-358',
#   'CWE-639',
#   'CWE-118',
#   'CWE-913',
#   'CWE-552',
#   'CWE-425',
#   'CWE-441',
#   'CWE-444',
#   'CWE-184',
#   'CWE-123',
#   'CWE-88',
#   'CWE-407',
#   'CWE-538',
#   'CWE-172',
#   'CWE-908',
#   'CWE-834',
#   'CWE-749',
#   'CWE-662',
#   'CWE-99',
#   'CWE-664',
#   'CWE-775',
#   'CWE-122',
#   'CWE-610',
#   'CWE-459',
#   'CWE-922',
#   'CWE-672',
#   'CWE-674',
#   'CWE-642',
#   'CWE-920',
#   'CWE-300',
#   'CWE-943',
#   'CWE-121',
#   'CWE-470',
#   'CWE-178',
#   'CWE-667',
#   'CWE-706',
#   'CWE-774',
#   'CWE-1236',
#   'CWE-212',
#   'CWE-288',
#   'CWE-266',
#   'CWE-915',
#   'CWE-185',
#   'CWE-917',
#   'CWE-924',
#   'CWE-405',
#   'CWE-436',
#   'CWE-471',
#   'CWE-707',
#   'CWE-838',
#   'CWE-256',
#   'CWE-321',
#   'CWE-317',
#   'CWE-573',
#   'CWE-305',
#   'CWE-406',
#   'CWE-61',
#   'CWE-23',
#   'CWE-313',
#   'CWE-778',
#   'CWE-73',
#   'CWE-325',
#   'CWE-268',
#   'CWE-440',
#   'CWE-280',
#   'CWE-80',
#   'CWE-250',
#   'CWE-349',
#   'CWE-805',
#   'CWE-261',
#   'CWE-684',
#   'CWE-114',
#   'CWE-350',
#   'CWE-364',
#   'CWE-117',
#   'CWE-385',
#   'CWE-201',
#   'CWE-506',
#   'CWE-303',
#   'CWE-248',
#   'CWE-757',
#   'CWE-912',
#   'CWE-1286',
#   'CWE-130',
#   'CWE-342',
#   'CWE-299',
#   'CWE-759',
#   'CWE-270',
#   'CWE-822',
#   'CWE-323',
#   'CWE-435',
#   'CWE-567',
#   'CWE-507',
#   'CWE-823',
#   'CWE-112',
#   'CWE-170',
#   'CWE-788',
#   'CWE-115',
#   'CWE-760',
#   'CWE-271',
#   'CWE-208',
#   'CWE-98',
#   'CWE-87',
#   'CWE-334',
#   'CWE-259',
#   'CWE-603',
#   'CWE-279',
#   'NVD-CWE-noinfo',
#   'NVD-CWE-Other',
#   'CWE-680',
#   'CWE-96',
#   'CWE-694',
#   'CWE-1285',
#   'CWE-183',
#   'CWE-228',
#   'CWE-214'])
